# %%
read.table('mgs.dat')->d

# %%
#alfa, delta, z, 5 mag petro, 5 enrojecimientos, 5 correciones k a .0, 5 correciones a .1
z <- d$V3
ku <-d$V14
kg <- d$V15
kr <- d$V16
ki <- d$V17
kz <- d$V18

# %%
#library(repr)
#options(repr.plot.width=3.5, repr.plot.height=3.5)
par(mfrow=c(5,1))
plot(z,ku,pch=19,cex=.1)
plot(z,kg,pch=19,cex=.1)
plot(z,kr,pch=19,cex=.1)
plot(z,ki,pch=19,cex=.1)
plot(z,kz,pch=19,cex=.1)
# Out:
# plot without title
