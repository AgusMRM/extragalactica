# %%
read.table('tabla2.csv',sep=',') -> d

# %%
pu <- d$V5-d$V15
pg <- d$V6-d$V16
pr <- d$V7-d$V17
pi <- d$V8-d$V18
pz <- d$V9-d$V19

# %%
mu <- d$V10-d$V15
mg <- d$V11-d$V16
mr <- d$V12-d$V17
mi <- d$V13-d$V18
mz <- d$V14-d$V19

# %%
z <- d$V3

# %%
for (i in 1:50000)
    {if (pu[i] > 14 & pu[i]<17) 
        pu[i]}

# %%
plot(z,pu)
# Out:
# plot without title
