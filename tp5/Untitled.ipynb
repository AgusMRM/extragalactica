# %%
read.table('field.dat') -> d

# %%
read.table('field.dat')-> d

smass <- d$V9
met <- d$V13
wp <- d$V14


x <- subset(smass, met > -99 & smass > 8 & smass < 12)
y <- subset(met, met> -99 & smass > 8 & smass < 12)
w <- subset(wp, met> -99 & smass > 8, smass < 12)



#plot(x,y,pch=19, cex=.1,col='grey',xlim=c(8,12),ylim=c(8,10))

library(MASS)

z <- kde2d(x,y,n=20)
#contour(z,col=terrain.colors(20))
filled.contour(z,color.palette=terrain.colors(20))
# Out:
# Warning message in pad1.rm.cm(widths, cm.widths, len = num.cols):
# “NAs introducidos por coerción”
# Error in plot.new(): outer margins too large (figure region too small)
# Traceback:
#
# 1. filled.contour(z, color.palette = terrain.colors(20))
# 2. plot.new()

# %%
library(repr)
options(repr.plot.width=4.5, repr.plot.height=4.5)
smass <- d$V9
met <- d$V13
wp <- d$V14
ssfr <- d$V11
d4 <- d$V12

# %%
x <- subset(smass, met > -99 & smass > 5)
y <- subset(met, met> -99 & smass > 5)
w <- subset(wp, met> -99 & smass > 5)



#plot(x,y,pch=19, cex=.1,col='grey',xlim=c(8,12),ylim=c(8,9.5))

# %%
read.table('31E.dat') -> SE
read.table('31L.dat') -> SL

read.table('32E.dat') -> SEZ
read.table('32L.dat') -> SLZ

# %%
options(repr.plot.width=12, repr.plot.height=6)
library(astro)
par(family='serif')
par(lwd=1)
par(cex=1)

par(mar=c(5,5,1,1))
par(mfrow=c(1,2))
par(mgp=c(1.2,.4,0))

#aplot(x,y,pch=19,cex=.1,col='grey',xlab=c('masa estelar'),ylab=c('metalicidad'),main=c('separado por indice de color'),xlim=c(7,12),ylim=c(8,9.4))
aplot(SE$V2,SE$V3,pch=17,col='red',type='o')
segments(SE$V2,SE$V3-SE$V4,SE$V2,SE$V3+SE$V5,col='red')
points(SL$V2,SL$V3,pch=19,col='darkblue',type='o')
segments(SL$V2,SL$V3-SL$V4,SL$V2,SL$V3+SL$V5,col='darkblue')

#aplot(x,y,pch=19,cex=.1,col='grey',xlab=c('masa estelar'),ylab=c('metalicidad'),main=c('separado por ZOO'),xlim=c(7,12),ylim=c(8,9.4))
aplot(SEZ$V2,SEZ$V3,pch=17,col='red',type='o')
segments(SEZ$V2,SEZ$V3-SEZ$V4,SEZ$V2,SEZ$V3+SEZ$V5,col='red')
points(SLZ$V2,SLZ$V3,pch=19,col='darkblue',type='o')
segments(SLZ$V2,SLZ$V3-SLZ$V4,SLZ$V2,SLZ$V3+SL$V5,col='darkblue')
# Out:
# plot without title

# %%
read.table('33blue.dat') -> SLur
read.table('33red.dat') -> SEur

read.table('33bred.dat') -> SEnv
read.table('33bblue.dat') ->SLnv

# %%
options(repr.plot.width=12, repr.plot.height=6)

par(family='serif')
par(lwd=1)
par(cex=1)

par(mar=c(5,5,1,1))
par(mfrow=c(1,2))
par(mgp=c(1.2,.4,0))


#aplot(x,y,pch=19,cex=.1,col='grey',xlab=c('masa estelar'),ylab=c('metalicidad'),main=c('separado por ur'))
aplot(SEur$V2,SEur$V3,pch=17,col='red',type='o')
segments(SEur$V2,SEur$V3-SEur$V4,SEur$V2,SEur$V3+SEur$V5,col='red')
points(SLur$V2,SLur$V3,pch=19,col='darkblue',type='o')
segments(SLur$V2,SLur$V3-SLur$V4,SLur$V2,SLur$V3+SLur$V5,col='darkblue')

#aplot(x,y,pch=19,cex=.1,col='grey',xlab=c('masa estelar'),ylab=c('metalicidad'),main=c('separado por nurv'))
aplot(SEnv$V2,SEnv$V3,pch=17,col='red',type='o')
segments(SEnv$V2,SEnv$V3-SEnv$V4,SEnv$V2,SEnv$V3+SEnv$V5,col='red')
points(SLnv$V2,SLnv$V3,pch=19,col='darkblue',type='o')
segments(SLnv$V2,SLnv$V3-SLnv$V4,SLnv$V2,SLnv$V3+SLnv$V5,col='darkblue')
# Out:
# plot without title

# %%
read.table('41E.dat') -> SE
read.table('41L.dat') -> SL

read.table('42L.dat') -> SLz
read.table('42E.dat') -> SEz

# %%
x <- subset(smass, ssfr > -20 & smass > 5)
y <- subset(ssfr, ssfr > -20 & smass > 5)

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(family='serif')
par(lwd=1)
par(cex=1)

par(mar=c(5,5,1,1))
par(mfrow=c(1,2))
par(mgp=c(1.2,.4,0))

aplot(x,y,pch=19,cex=.1,col='grey',main=c('separadas por indice de concentracion'))
points(SE$V2,SE$V3,pch=17,col='red',type='o')
segments(SE$V2,SE$V3-SE$V4,SE$V2,SE$V3+SE$V5,col='red')
points(SL$V2,SL$V3,pch=19,col='darkblue',type='o')
segments(SL$V2,SL$V3-SL$V4,SL$V2,SL$V3+SL$V5,col='darkblue')

aplot(x,y,pch=19,cex=.1,col='grey',main=c('ZOO'),xlab=c('masa estelar'),ylab=c('SSFR'))
points(SEz$V2,SEz$V3,pch=17,col='red',type='o')
segments(SEz$V2,SEz$V3-SEz$V4,SEz$V2,SEz$V3+SEz$V5,col='red')
points(SLz$V2,SLz$V3,pch=19,col='darkblue',type='o')
segments(SLz$V2,SLz$V3-SLz$V4,SLz$V2,SLz$V3+SLz$V5,col='darkblue')
# Out:
# Plot with title “ZOO”

# %%
read.table('43_red.dat') -> SEur
read.table('43_blue.dat') -> SLur

read.table('43b_red.dat') -> SEnv
read.table('43b_blue.dat') -> SLnv

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(family='serif')
par(lwd=1)
par(cex=1)

par(mar=c(5,5,1,1))
par(mfrow=c(1,2))
par(mgp=c(1.2,.4,0))

aplot(x,y,pch=19,cex=.1,col='grey',main=c('separado por ur'),xlab=c('masa estelar'),ylab=c('SSFR'))
points(SEur$V2,SEur$V3,pch=17,col='red',type='o')
segments(SEur$V2,SEur$V3-SEur$V4,SEur$V2,SEur$V3+SEur$V5,col='red')
points(SLur$V2,SLur$V3,pch=19,col='darkblue',type='o')
segments(SLur$V2,SLur$V3-SLur$V4,SLur$V2,SLur$V3+SLur$V5,col='darkblue')

aplot(x,y,pch=19,cex=.1,col='grey',main=c('separados por nuv'),xlab=c('masa estelar'),ylab=c('SSFR'))
points(SEnv$V2,SEnv$V3,pch=17,col='red',type='o')
segments(SEnv$V2,SEnv$V3-SEnv$V4,SEnv$V2,SEnv$V3+SEnv$V5,col='red')
points(SLnv$V2,SLnv$V3,pch=19,col='darkblue',type='o')
segments(SLnv$V2,SLnv$V3-SLnv$V4,SLnv$V2,SLnv$V3+SLnv$V5,col='darkblue')
# Out:
# Plot with title “separados por nuv”

# %%
x <- subset(smass, smass > 5 & d4 > 0 & d4 < 3 )
y <- subset(d4,smass > 5 & d4 > 0 & d4 < 3)

# %%
hist(y,breaks=20,density=40)
# Out:
# Plot with title “Histogram of y”

# %%
read.table('51_E.dat') -> SE
read.table('51_L.dat') -> SL

read.table('52E.dat') -> SEz
read.table('52L.dat') -> SLz

# %%
options(repr.plot.width=12, repr.plot.height=6)
par(family='serif')
par(lwd=1)
par(cex=1)

par(mar=c(5,5,1,1))
par(mfrow=c(1,2))
par(mgp=c(1.2,.4,0))


aplot(x,y,pch=19,cex=.1,col='grey',main=c('separados por indice de concentracion'),xlab=c('masa estelar'),ylab=c('Dn4000'))
points(SE$V2,SE$V3,pch=17,col='red',type='o')
segments(SE$V2,SE$V3-SE$V4,SE$V2,SE$V3+SE$V5,col='red')
points(SL$V2,SL$V3,pch=19,col='darkblue',type='o')
segments(SL$V2,SL$V3-SL$V4,SL$V2,SL$V3+SL$V5,col='darkblue')

aplot(x,y,pch=19,cex=.1,col='grey',main=c('separados por ZOO'),xlab=c('masa estelar'),ylab=c('Dn4000'))
points(SEz$V2,SEz$V3,pch=17,col='red',type='o')
segments(SEz$V2,SEz$V3-SEz$V4,SEz$V2,SEz$V3+SEz$V5,col='red')
points(SLz$V2,SLz$V3,pch=19,col='darkblue',type='o')
segments(SLz$V2,SLz$V3-SLz$V4,SLz$V2,SLz$V3+SLz$V5,col='darkblue')

#probar pesando
# Out:
# Plot with title “separados por ZOO”

# %%
read.table('53_blue.dat') -> SL
read.table('53_red.dat') -> SE

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(x,y,pch=19,cex=.1,col='grey',main=c('separados por ur'),xlab=c('masa estelar'),ylab='DN4000')
points(SE$V2,SE$V3,pch=17,col='red',type='o')
segments(SE$V2,SE$V3-SE$V4,SE$V2,SE$V3+SE$V5,col='red')
points(SL$V2,SL$V3,pch=19,col='darkblue',type='o')
segments(SL$V2,SL$V3-SL$V4,SL$V2,SL$V3+SL$V5,col='darkblue')
# Out:
# Plot with title “separados por ur”

# %%
read.table('53b_blue.dat') -> SL
read.table('53b_red.dat') -> SE

# %%
options(repr.plot.width=6, repr.plot.height=6)
plot(x,y,pch=19,cex=.1,col='grey',main=c('separados por nuv'),xlab=c('masa estelar'),ylab=c('dn4000'))
points(SE$V2,SE$V3,pch=17,col='red',type='o')
segments(SE$V2,SE$V3-SE$V4,SE$V2,SE$V3+SE$V5,col='red')
points(SL$V2,SL$V3,pch=19,col='darkblue',type='o')
segments(SL$V2,SL$V3-SL$V4,SL$V2,SL$V3+SL$V5,col='darkblue')
# Out:
# Plot with title “separados por nuv”
